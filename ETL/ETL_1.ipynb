# %% [markdown]
# # <center>📦🧹🔍ETL 🔍🧹📦<center>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#¿Qué-significa-ETL?" data-toc-modified-id="¿Qué-significa-ETL?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>¿Qué significa ETL?</a></span></li><li><span><a href="#¿Qué-vamos-a-hacer?" data-toc-modified-id="¿Qué-vamos-a-hacer?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>¿Qué vamos a hacer?</a></span></li><li><span><a href="#Importamos-librerías" data-toc-modified-id="Importamos-librerías-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Importamos librerías</a></span></li><li><span><a href="#Misión-1" data-toc-modified-id="Misión-1-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Misión 1</a></span></li><li><span><a href="#Token-spotify" data-toc-modified-id="Token-spotify-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Token spotify</a></span></li><li><span><a href="#Salvamos-el-token-en-nuestro-.env" data-toc-modified-id="Salvamos-el-token-en-nuestro-.env-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Salvamos el token en nuestro .env</a></span></li><li><span><a href="#📚-Recap-hasta-ahora:" data-toc-modified-id="📚-Recap-hasta-ahora:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>📚 Recap hasta ahora:</a></span></li><li><span><a href="#Misión-2" data-toc-modified-id="Misión-2-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Misión 2</a></span><ul class="toc-item"><li><span><a href="#Llamada-a-API-Spotify" data-toc-modified-id="Llamada-a-API-Spotify-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Llamada a API Spotify</a></span><ul class="toc-item"><li><span><a href="#Necesitamos-token-y-headers" data-toc-modified-id="Necesitamos-token-y-headers-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Necesitamos token y headers</a></span></li><li><span><a href="#Url-+-endpoint" data-toc-modified-id="Url-+-endpoint-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Url + endpoint</a></span></li><li><span><a href="#Hacemos-la-request" data-toc-modified-id="Hacemos-la-request-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>Hacemos la request</a></span></li></ul></li><li><span><a href="#Nos-enfrentamos-al-json-de-la-response" data-toc-modified-id="Nos-enfrentamos-al-json-de-la-response-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Nos enfrentamos al json de la response</a></span><ul class="toc-item"><li><span><a href="#Extraemos-las-canciones" data-toc-modified-id="Extraemos-las-canciones-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Extraemos las canciones</a></span></li><li><span><a href="#Extraemos-los-artistas-de-las-canciones" data-toc-modified-id="Extraemos-los-artistas-de-las-canciones-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Extraemos los artistas de las canciones</a></span></li><li><span><a href="#Extraemos-los-users-que-han-añadido-la-canción-a-la-lista" data-toc-modified-id="Extraemos-los-users-que-han-añadido-la-canción-a-la-lista-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>Extraemos los users que han añadido la canción a la lista</a></span></li><li><span><a href="#Extraemoz-el-nombre-de-la-canción" data-toc-modified-id="Extraemoz-el-nombre-de-la-canción-8.2.4"><span class="toc-item-num">8.2.4&nbsp;&nbsp;</span>Extraemoz el nombre de la canción</a></span></li></ul></li><li><span><a href="#¡Nos-lo-llevamos-a-Pandas!-🐼" data-toc-modified-id="¡Nos-lo-llevamos-a-Pandas!-🐼-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>¡Nos lo llevamos a Pandas! 🐼</a></span></li></ul></li><li><span><a href="#Automatizamos-procesos" data-toc-modified-id="Automatizamos-procesos-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Automatizamos procesos</a></span></li><li><span><a href="#Misión-3" data-toc-modified-id="Misión-3-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Misión 3</a></span></li><li><span><a href="#Extraemos-letras-de-las-canciones!" data-toc-modified-id="Extraemos-letras-de-las-canciones!-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Extraemos letras de las canciones!</a></span><ul class="toc-item"><li><span><a href="#Necesitamos-crear-las-KEYs-para-esta-librería" data-toc-modified-id="Necesitamos-crear-las-KEYs-para-esta-librería-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Necesitamos crear las KEYs para esta librería</a></span></li><li><span><a href="#Como-la-librería-necesita-las-keys,-las-sacamos-del-.env" data-toc-modified-id="Como-la-librería-necesita-las-keys,-las-sacamos-del-.env-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Como la librería necesita las keys, las sacamos del .env</a></span></li><li><span><a href="#La-guardamos-en-una-variable" data-toc-modified-id="La-guardamos-en-una-variable-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>La guardamos en una variable</a></span></li><li><span><a href="#Buscamos-una-letra" data-toc-modified-id="Buscamos-una-letra-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Buscamos una letra</a></span></li><li><span><a href="#¡¡Muchas-letras!!" data-toc-modified-id="¡¡Muchas-letras!!-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>¡¡Muchas letras!!</a></span></li><li><span><a href="#Creamos-una-columna-nueva-con-las-letras" data-toc-modified-id="Creamos-una-columna-nueva-con-las-letras-11.6"><span class="toc-item-num">11.6&nbsp;&nbsp;</span>Creamos una columna nueva con las letras</a></span></li><li><span><a href="#Exportamos-los-datos" data-toc-modified-id="Exportamos-los-datos-11.7"><span class="toc-item-num">11.7&nbsp;&nbsp;</span>Exportamos los datos</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![data](https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy.gif)

# %% [markdown]
# ## ¿Qué significa ETL?
# **Extract**, **Transform** and **Load** es el proceso que permite a las organizaciones mover datos desde múltiples fuentes, reformatearlos y limpiarlos, y cargarlos en otra base de datos, data mart, o data warehouse para analizar, o en otro sistema operacional para apoyar un proceso de negocio.

# %% [markdown]
# ## ¿Qué vamos a hacer?
# - Aprender a usar la API de spotify con Oauth
# - Extraer datos de dicha API
# - Limpiarlos y transformarlos
# - Enriquecerlos
# - Guardarlos en diferentes bases de datos
# - Hacer queries para hacer análisis de sentimientos con librerías NLP

# %% [markdown]
# ## Importamos librerías

# %%
import os
import json
import requests
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Misión 1
#  # <center> Obtener el token de Spotify para hacer uso de su API 🗝</center>

# %% [markdown]
# ## Token spotify
# https://developer.spotify.com/dashboard/login
# Necesitamos tener los token CLIENT_ID y SECRET_ID, y los guardamos en el .env.
# Para llamar a la aapi de spotify y conseguir el token que nos va a permitir hacer request, vamos a tener que guardar unas cuantas variables.
# Leed la [Documentación](https://developer.spotify.com/documentation/general/guides/authorization-guide/)

# %%
# Autenticación
CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")

#Scope del token
body_params = {"grant_type": "client_credentials"}

#Url a la que pedimos el token
url = "https://accounts.spotify.com/api/token"
    
#La request
response = requests.post(url, data= body_params, auth = (CLIENT_ID, CLIENT_SECRET), verify=False)

# %%
response.headers

# %%
#El token
token_raw = json.loads(response.text)

# %%
token_raw

# %% [markdown]
# Vamos a escribir todo esto en una función porque, como hemos visto, el token expira y así podemos llamarla cuando queramos y reutilizarla. ¡Para esto sirven las funciones!

# %%
def spotifyToken():
    #Autenticación
    CLIENT_ID = os.getenv("CLIENT_ID")
    CLIENT_SECRET = os.getenv("CLIENT_SECRET")

    #Scope del token
    body_params = {"grant_type": "client_credentials"}

    #Url a la que pedimos el token
    url = "https://accounts.spotify.com/api/token"

    #La request
    response = requests.post(url, data= body_params, auth = (CLIENT_ID, CLIENT_SECRET), verify=False)
    
    #EL TOKEN
    token_raw = json.loads(response.text)
    
    try: 
        token = token_raw["access_token"]
        return token
    except:
        return token_raw

# %%
# SACO EL TOKEN LLAMANDO A LA FUNCIÓN
token = spotifyToken()

# %%
#token

# %% [markdown]
# ## Salvamos el token en nuestro .env

# %%
file = open("../.env", "a")
file.write("\n")
file.write(f"token={spotifyToken()}")
file.close()

# %% [markdown]
# Hacemos unan función que hace lo mismo para poder reutilizarla

# %%
def salva_env(nombre,key):
    file = open("../.env", "a")
    file.write("\n")
    file.write(f"{nombre}={key}")
    file.close()

# %%
salva_env("token",spotifyToken())
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'accounts.spotify.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ## 📚 Recap hasta ahora:
#
# **Lo que hemos hecho**
# - 1. Conseguimos nuestra autentificación de Spotify
# - 2. Con eso, conseguimos nuestro `token` de spotify
# - 3. Guardamos el `token` en el .env <br>
# <br>
#
# **Para recordar**
#
# - **CLIENT_ID** & **CLIENT_SECRET** es sólo un medio para obtener el `token`, no la autenticidad en sí.
# - El `token` expira

# %% [markdown]
#  ## Misión 2
#  # <center> Obtener la lista de canciones y artistas de la API de Spotify 🔥</center>
# Pero no vayamos a olvidarnos de la [documentación](https://developer.spotify.com/console/)
# Lo primero que vamos a hacer es una llamada a la API
# Recordemos la sintaxis:
#
#
# `request.get(url, headers)`

# %% [markdown]
# ### Llamada a API Spotify

# %% [markdown]
# #### Necesitamos token y headers

# %%
# Por si necesitáramos el token, aunque ya lo tenemos
token = os.getenv("token")

# %%
#token

# %%
headers = {"Authorization": f"Bearer {token}"}

# %% [markdown]
# #### Url + endpoint

# %%
url_base = "https://api.spotify.com/v1/"

# %% [markdown]
# El ID de la lista de la cual queremos hacer la request

# %%
playlist = "6hrGEF3uh9ZZtn2WrpLqNK"

# %%
endpoint = f"playlists/{playlist}"

# %%
endpoint
# Out:
# 'playlists/6hrGEF3uh9ZZtn2WrpLqNK'

# %%
query  = url_base + endpoint
query
# Out:
# 'https://api.spotify.com/v1/playlists/6hrGEF3uh9ZZtn2WrpLqNK'

# %% [markdown]
# #### Hacemos la request

# %%
response = requests.get(query, headers = headers).json()

# %%
#response

# %% [markdown]
# ### Nos enfrentamos al json de la response

# %%
import pandas as pd

# %%
#response

# %%
import pandas as pd
df = pd.json_normalize(response)
df
# Out:
#    collaborative description  \
# 0           True
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/6hrGEF3uh...  6hrGEF3uh9ZZtn2WrpLqNK
#
#                                               images           name  \
# 0  [{'height': 640, 'url': 'https://mosaic.scdn.c...  datamad0321 🚀
#
#   primary_color  public                                        snapshot_id  \
# 0          None   False  MTE3LDY3ZTAyY2M3NGUxNjIzOWFmYzQyOTUwNjZjMTUwOT...
#
#        type  ...       owner.id owner.type                   owner.uri  \
# 0  playlist  ...  ferqwertyuiop       user  spotify:user:ferqwertyuiop
#
#                                          tracks.href  \
# 0  https://api.spotify.com/v1/playlists/6hrGEF3uh...
#
#                                         tracks.items tracks.limit tracks.next  \
# 0  [{'added_at': '2021-03-23T14:48:50Z', 'added_b...          100        None
#
#   tracks.offset tracks.previous tracks.total
# 0             0            None           81
#
# [1 rows x 27 columns]

# %%
response.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
response["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# #### Extraemos las canciones

# %%
# Vamos a obtener solo las canciones
# EL VALUE DE ITEMS ES UNA LISTA CON UN DICCIONARIO POR CADA CANCIÓN 
cada_cancion = response["tracks"]["items"]
#cada_cancion[0]
# Out:
# {'added_at': '2021-03-23T14:48:50Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#   'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#   'id': 'ferqwertyuiop',
#   'type': 'user',
#   'uri': 'spotify:user:ferqwertyuiop'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1D5DI6S5zIiGPBf1IAuAJh'},
#      'href': 'https://api.spotify.com/v1/artists/1D5DI6S5zIiGPBf1IAuAJh',
#      'id': '1D5DI6S5zIiGPBf1IAuAJh',
#      'name': 'Hocus Pocus',
#      'type': 'artist',
#      'uri': 'spotify:artist:1D5DI6S5zIiGPBf1IAuAJh'}],
#    'available_markets': ['AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LV',
#     'MA',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2CUaOITIR3MWLvccLmNLnv'},
#    'href': 'https://api.spotify.com/v1/albums/2CUaOITIR3MWLvccLmNLnv',
#    'id': '2CUaOITIR3MWLvccLmNLnv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c5d3a1571436bd4b87dd1b46',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c5d3a1571436bd4b87dd1b46',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c5d3a1571436bd4b87dd1b46',
#      'width': 64}],
#    'name': '73 touches',
#    'release_date': '2005',
#    'release_date_precision': 'year',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:2CUaOITIR3MWLvccLmNLnv'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1D5DI6S5zIiGPBf1IAuAJh'},
#     'href': 'https://api.spotify.com/v1/artists/1D5DI6S5zIiGPBf1IAuAJh',
#     'id': '1D5DI6S5zIiGPBf1IAuAJh',
#     'name': 'Hocus Pocus',
#     'type': 'artist',
#     'uri': 'spotify:artist:1D5DI6S5zIiGPBf1IAuAJh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/05FiSO3cAdb65CQ2soSaE3'},
#     'href': 'https://api.spotify.com/v1/artists/05FiSO3cAdb65CQ2soSaE3',
#     'id': '05FiSO3cAdb65CQ2soSaE3',
#     'name': 'The Procussions',
#     'type': 'artist',
#     'uri': 'spotify:artist:05FiSO3cAdb65CQ2soSaE3'}],
#   'available_markets': ['AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LV',
#    'MA',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 261813,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR9T30500010'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/63UKeR6Kprg9H50f4UnVVT'},
#   'href': 'https://api.spotify.com/v1/tracks/63UKeR6Kprg9H50f4UnVVT',
#   'id': '63UKeR6Kprg9H50f4UnVVT',
#   'is_local': False,
#   'name': 'Hip Hop ?',
#   'popularity': 30,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7c694250063b30e22933d4be2e3b8964c57583e7?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#   'track': True,
#   'track_number': 18,
#   'type': 'track',
#   'uri': 'spotify:track:63UKeR6Kprg9H50f4UnVVT'},
#  'video_thumbnail': {'url': None}}

# %%
df = pd.json_normalize(response["tracks"]["items"])

# %% [markdown]
# #### Extraemos los artistas de las canciones

# %%
artista = cada_cancion[80]["track"]["artists"][0]["name"]
artista
# Out:
# 'Calavera'

# %%
#Explorad este diccionario con calma que es un poco dolorsito, sorry  :) 
cada_cancion[80]
# Out:
# {'added_at': '2021-06-17T18:01:42Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyungalgo'},
#   'href': 'https://api.spotify.com/v1/users/soyungalgo',
#   'id': 'soyungalgo',
#   'type': 'user',
#   'uri': 'spotify:user:soyungalgo'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/507kgzh6KhdPS644SYP75C'},
#      'href': 'https://api.spotify.com/v1/artists/507kgzh6KhdPS644SYP75C',
#      'id': '507kgzh6KhdPS644SYP75C',
#      'name': 'Calavera',
#      'type': 'artist',
#      'uri': 'spotify:artist:507kgzh6KhdPS644SYP75C'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/71Aj7SgHCTg6jfbo3jwEEf'},
#    'href': 'https://api.spotify.com/v1/albums/71Aj7SgHCTg6jfbo3jwEEf',
#    'id': '71Aj7SgHCTg6jfbo3jwEEf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27353c1d9707dac53155cfda21b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0253c1d9707dac53155cfda21b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485153c1d9707dac53155cfda21b',
#      'width': 64}],
#    'name': 'Espejismos',
#    'release_date': '2021-04-09',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:71Aj7SgHCTg6jfbo3jwEEf'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/507kgzh6KhdPS644SYP75C'},
#     'href': 'https://api.spotify.com/v1/artists/507kgzh6KhdPS644SYP75C',
#     'id': '507kgzh6KhdPS644SYP75C',
#     'name': 'Calavera',
#     'type': 'artist',
#     'uri': 'spotify:artist:507kgzh6KhdPS644SYP75C'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 294097,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'USA2P1951215'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/063PnKY4bvJiqJ3YQXrKyt'},
#   'href': 'https://api.spotify.com/v1/tracks/063PnKY4bvJiqJ3YQXrKyt',
#   'id': '063PnKY4bvJiqJ3YQXrKyt',
#   'is_local': False,
#   'name': 'No te das cuenta',
#   'popularity': 17,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0174f27f991b90fe2b97fb7f096fcd643e9eafce?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#   'track': True,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:063PnKY4bvJiqJ3YQXrKyt'},
#  'video_thumbnail': {'url': None}}

# %%
len(cada_cancion)
# Out:
# 81

# %% [markdown]
# #### Extraemos los users que han añadido la canción a la lista

# %%
usuario = cada_cancion[80]["added_by"]["id"]
usuario
# Out:
# 'soyungalgo'

# %% [markdown]
# #### Extraemoz el nombre de la canción

# %%
nombre = cada_cancion[80]["track"]["name"]
nombre
# Out:
# 'No te das cuenta'

# %% [markdown]
# ### ¡Nos lo llevamos a Pandas! 🐼
# ¿Cómo? Vamos a iterar por toda la lista de canciones y hacemos una lista de diccionarios con la información que necesitamos para hacernos un dataframe

# %%
toda_info = []
for tema in range(len(cada_cancion)):
    temporal = {}
    temporal["artista"] = cada_cancion[tema]["track"]["artists"][0]["name"]
    temporal["nombre"] = cada_cancion[tema]["track"]["name"]
    temporal["ironhacker"] = cada_cancion[tema]["added_by"]["id"]
    toda_info.append(temporal)

# %%
df = pd.DataFrame(toda_info)
df.sample(10)
# Out:
#                           artista                               nombre  \
# 2                    Dominic Fike                        Phone Numbers
# 69                 Arctic Monkeys                        Dancing Shoes
# 1                        rusowsky                                So So
# 73               Michael Kiwanuka       Cold Little Heart - Radio Edit
# 20                   Channel Tres                              Topdown
# 38                          Queen  Don't Stop Me Now - Remastered 2011
# 72                 Kendrick Lamar                  LOVE. FEAT. ZACARI.
# 54                         Boikot       Salgo a la Calle (Bonus Track)
# 22                     Marc Seguí                              Gameboi
# 11  Me First and the Gimme Gimmes                      Favorite Things
#
#            ironhacker
# 2       ferqwertyuiop
# 69  javiercabrera9627
# 1       ferqwertyuiop
# 73        11124266126
# 20  javiercabrera9627
# 38         1183037273
# 72  javiercabrera9627
# 54         1183037273
# 22         soyungalgo
# 11              entzo

# %% [markdown]
# ## Automatizamos procesos
# Todo lo que vamos escribiendo en líneas de código, podemos hacerlo con funciones, y que estas funciones nos sirvan para poder hacer el mismo proceso con un par de funciones

# %%
def spotifyPlaylist(playlist_id):
    '''Esto devolverá la información de una determinada lista de reproducción de Spotify.
    Args: playlist_id como string
    Devuelve: json'''
    
    token = os.getenv("token") #coge el token del .env
    headers = {'Authorization': f'Bearer {token}'} #forma de pasarle el token está en la doc
    url_base = "https://api.spotify.com/v1/" #url básica de la api
    endpoint = f"playlists/{playlist_id}"
    query = url_base + endpoint
    lista = requests.get(query, headers = headers)
    
    return lista.json()

# %%
play = spotifyPlaylist("4UbChG0JiHRFrwjvQvG2LJ")

# %%
play
# Out:
# {'collaborative': True,
#  'description': '¡Que empiece la parranda! ',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/4UbChG0JiHRFrwjvQvG2LJ'},
#  'followers': {'href': None, 'total': 8},
#  'href': 'https://api.spotify.com/v1/playlists/4UbChG0JiHRFrwjvQvG2LJ',
#  'id': '4UbChG0JiHRFrwjvQvG2LJ',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732fb16736d70cb63772673d39ab67616d0000b273a9870df8eecb7f1ee66171a5ab67616d0000b273ad8fa6fc890783cb2d31f278ab67616d0000b273bcbb9396eb2c0673c0005ef2',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732fb16736d70cb63772673d39ab67616d0000b273a9870df8eecb7f1ee66171a5ab67616d0000b273ad8fa6fc890783cb2d31f278ab67616d0000b273bcbb9396eb2c0673c0005ef2',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732fb16736d70cb63772673d39ab67616d0000b273a9870df8eecb7f1ee66171a5ab67616d0000b273ad8fa6fc890783cb2d31f278ab67616d0000b273bcbb9396eb2c0673c0005ef2',
#    'width': 60}],
#  'name': 'DataMad0121 - 🔥🚀💻',
#  'owner': {'display_name': 'soyungalgo',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/soyungalgo'},
#   'href': 'https://api.spotify.com/v1/users/soyungalgo',
#   'id': 'soyungalgo',
#   'type': 'user',
#   'uri': 'spotify:user:soyungalgo'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'NzQsMmUwNDljMzc4MzAxOGVlZWNkNWEwM2NiNzBhYjgzMDhkMjExMGU4Mg==',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/4UbChG0JiHRFrwjvQvG2LJ/tracks?offset=0&limit=100',
#   'items': [{'added_at': '2021-01-15T17:39:35Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyungalgo'},
#      'href': 'https://api.spotify.com/v1/users/soyungalgo',
#      'id': 'soyungalgo',
#      'type': 'user',
#      'uri': 'spotify:user:soyungalgo'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MbqzxZvHtdClX1cBKU2OG'},
#         'href': 'https://api.spotify.com/v1/artists/1MbqzxZvHtdClX1cBKU2OG',
#         'id': '1MbqzxZvHtdClX1cBKU2OG',
#         'name': 'Fuel Fandango',
#         'type': 'artist',
#         'uri': 'spotify:artist:1MbqzxZvHtdClX1cBKU2OG'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6NqYTQiv0OluEf9u3vwbtS'},
#       'href': 'https://api.spotify.com/v1/albums/6NqYTQiv0OluEf9u3vwbtS',
#       'id': '6NqYTQiv0OluEf9u3vwbtS',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732fb16736d70cb63772673d39',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022fb16736d70cb63772673d39',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512fb16736d70cb63772673d39',
#         'width': 64}],
#       'name': 'Origen',
#       'release_date': '2020-01-24',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:6NqYTQiv0OluEf9u3vwbtS'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MbqzxZvHtdClX1cBKU2OG'},
#        'href': 'https://api.spotify.com/v1/artists/1MbqzxZvHtdClX1cBKU2OG',
#        'id': '1MbqzxZvHtdClX1cBKU2OG',
#        'name': 'Fuel Fandango',
#        'type': 'artist',
#        'uri': 'spotify:artist:1MbqzxZvHtdClX1cBKU2OG'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5q5hdofWygpLCkmorAyttW'},
#        'href': 'https://api.spotify.com/v1/artists/5q5hdofWygpLCkmorAyttW',
#        'id': '5q5hdofWygpLCkmorAyttW',
#        'name': 'Dani de Morón',
#        'type': 'artist',
#        'uri': 'spotify:artist:5q5hdofWygpLCkmorAyttW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 196266,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'ES5151901412'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7kQPuYOoKgLR0PF0BtKHD5'},
#      'href': 'https://api.spotify.com/v1/tracks/7kQPuYOoKgLR0PF0BtKHD5',
#      'id': '7kQPuYOoKgLR0PF0BtKHD5',
#      'is_local': False,
#      'name': 'Mi danza (feat. Dani de Morón)',
#      'popularity': 42,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7de1f12ef5b05d71c03b90bfb6124d3fb1fef04a?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:7kQPuYOoKgLR0PF0BtKHD5'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-01-15T17:39:44Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyungalgo'},
#      'href': 'https://api.spotify.com/v1/users/soyungalgo',
#      'id': 'soyungalgo',
#      'type': 'user',
#      'uri': 'spotify:user:soyungalgo'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7uLePkJ2f0MwEcphODfkuu'},
#         'href': 'https://api.spotify.com/v1/artists/7uLePkJ2f0MwEcphODfkuu',
#         'id': '7uLePkJ2f0MwEcphODfkuu',
#         'name': 'Zahara',
#         'type': 'artist',
#         'uri': 'spotify:artist:7uLePkJ2f0MwEcphODfkuu'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/54nYgqxVh8JMLdxOUBXAWC'},
#       'href': 'https://api.spotify.com/v1/albums/54nYgqxVh8JMLdxOUBXAWC',
#       'id': '54nYgqxVh8JMLdxOUBXAWC',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273bcbb9396eb2c0673c0005ef2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02bcbb9396eb2c0673c0005ef2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851bcbb9396eb2c0673c0005ef2',
#         'width': 64}],
#       'name': 'MERICHANE',
#       'release_date': '2021-01-14',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:54nYgqxVh8JMLdxOUBXAWC'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7uLePkJ2f0MwEcphODfkuu'},
#        'href': 'https://api.spotify.com/v1/artists/7uLePkJ2f0MwEcphODfkuu',
#        'id': '7uLePkJ2f0MwEcphODfkuu',
#        'name': 'Zahara',
#        'type': 'artist',
#        'uri': 'spotify:artist:7uLePkJ2f0MwEcphODfkuu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 261129,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'ES71G2058194'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5Wo5vynGiUDG4nWJYJsZ5y'},
#      'href': 'https://api.spotify.com/v1/tracks/5Wo5vynGiUDG4nWJYJsZ5y',
#      'id': '5Wo5vynGiUDG4nWJYJsZ5y',
#      'is_local': False,
#      'name': 'MERICHANE',
#      'popularity': 49,
#      'preview_url': 'https://p.scdn.co/mp3-preview/ab9fec7e5f04849bc3511bb59cf2dcff9ac05aa3?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5Wo5vynGiUDG4nWJYJsZ5y'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-01-15T17:54:04Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/toni085'},
#      'href': 'https://api.spotify.com/v1/users/toni085',
#      'id': 'toni085',
#      'type': 'user',
#      'uri': 'spotify:user:toni085'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6arRVLZ3vn5AXkuvp9JxbS'},
#         'href': 'https://api.spotify.com/v1/artists/6arRVLZ3vn5AXkuvp9JxbS',
#         'id': '6arRVLZ3vn5AXkuvp9JxbS',
#         'name': 'LOS NIKIS',
#         'type': 'artist',
#         'uri': 'spotify:artist:6arRVLZ3vn5AXkuvp9JxbS'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Gl1kSSy7uO04VggpET539'},
#       'href': 'https://api.spotify.com/v1/albums/2Gl1kSSy7uO04VggpET539',
#       'id': '2Gl1kSSy7uO04VggpET539',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273ad8fa6fc890783cb2d31f278',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02ad8fa6fc890783cb2d31f278',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851ad8fa6fc890783cb2d31f278',
#         'width': 64}],
#       'name': 'Marines A Pleno Sol',
#       'release_date': '1986-04-04',
#       'release_date_precision': 'day',
#       'total_tracks': 16,
#       'type': 'album',
#       'uri': 'spotify:album:2Gl1kSSy7uO04VggpET539'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6arRVLZ3vn5AXkuvp9JxbS'},
#        'href': 'https://api.spotify.com/v1/artists/6arRVLZ3vn5AXkuvp9JxbS',
#        'id': '6arRVLZ3vn5AXkuvp9JxbS',
#        'name': 'LOS NIKIS',
#        'type': 'artist',
#        'uri': 'spotify:artist:6arRVLZ3vn5AXkuvp9JxbS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 152106,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'ES5018534006'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/15BlyjTfsahHOvvyUAnvum'},
#      'href': 'https://api.spotify.com/v1/tracks/15BlyjTfsahHOvvyUAnvum',
#      'id': '15BlyjTfsahHOvvyUAnvum',
#      'is_local': False,
#      'name': 'Olaf el vikingo',
#      'popularity': 21,
#      'preview_url': 'https://p.scdn.co/mp3-preview/fcb4f57b44a318249203c2c83a4f6c52432e0359?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:15BlyjTfsahHOvvyUAnvum'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-01-17T09:50:49Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#      'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#      'id': 'ferqwertyuiop',
#      'type': 'user',
#      'uri': 'spotify:user:ferqwertyuiop'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1XEVu7gdRFfzEFqsPrancH'},
#         'href': 'https://api.spotify.com/v1/artists/1XEVu7gdRFfzEFqsPrancH',
#         'id': '1XEVu7gdRFfzEFqsPrancH',
#         'name': 'rusowsky',
#         'type': 'artist',
#         'uri': 'spotify:artist:1XEVu7gdRFfzEFqsPrancH'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2zKh0nXe1RCtyy3qwVPFP2'},
#       'href': 'https://api.spotify.com/v1/albums/2zKh0nXe1RCtyy3qwVPFP2',
#       'id': '2zKh0nXe1RCtyy3qwVPFP2',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734d4fe5195d28a760601efeb2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024d4fe5195d28a760601efeb2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514d4fe5195d28a760601efeb2',
#         'width': 64}],
#       'name': 'So So',
#       'release_date': '2019-09-19',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:2zKh0nXe1RCtyy3qwVPFP2'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1XEVu7gdRFfzEFqsPrancH'},
#        'href': 'https://api.spotify.com/v1/artists/1XEVu7gdRFfzEFqsPrancH',
#        'id': '1XEVu7gdRFfzEFqsPrancH',
#        'name': 'rusowsky',
#        'type': 'artist',
#        'uri': 'spotify:artist:1XEVu7gdRFfzEFqsPrancH'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 125557,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'AEA0Q1971039'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1ELqVqsAN0nmwdJFKJlS2n'},
#      'href': 'https://api.spotify.com/v1/tracks/1ELqVqsAN0nmwdJFKJlS2n',
#      'id': '1ELqVqsAN0nmwdJFKJlS2n',
#      'is_local': False,
#      'name': 'So So',
#      'popularity': 38,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1ELqVqsAN0nmwdJFKJlS2n'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-01-17T10:29:21Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1182774545'},
#      'href': 'https://api.spotify.com/v1/users/1182774545',
#      'id': '1182774545',
#      'type': 'user',
#      'uri': 'spotify:user:1182774545'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xLtt3vnhKGANQKpsaIMVa'},
#         'href': 'https://api.spotify.com/v1/artists/7xLtt3vnhKGANQKpsaIMVa',
#         'id': '7xLtt3vnhKGANQKpsaIMVa',
#         'name': 'Chico Blanco',
#         'type': 'artist',
#         'uri': 'spotify:artist:7xLtt3vnhKGANQKpsaIMVa'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/64sTPt8sHRwmqpTq63jmEV'},
#       'href': 'https://api.spotify.com/v1/albums/64sTPt8sHRwmqpTq63jmEV',
#       'id': '64sTPt8sHRwmqpTq63jmEV',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394fb9bc1da135ff8b72a79dc',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294fb9bc1da135ff8b72a79dc',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194fb9bc1da135ff8b72a79dc',
#         'width': 64}],
#       'name': 'WTF Is In My Cup',
#       'release_date': '2018-06-04',
#       'release_date_precision': 'day',
#       'total_tracks': 2,
#       'type': 'album',
#       'uri': 'spotify:album:64sTPt8sHRwmqpTq63jmEV'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xLtt3vnhKGANQKpsaIMVa'},
#        'href': 'https://api.spotify.com/v1/artists/7xLtt3vnhKGANQKpsaIMVa',
#        'id': '7xLtt3vnhKGANQKpsaIMVa',
#        'name': 'Chico Blanco',
#        'type': 'artist',
#        'uri': 'spotify:artist:7xLtt3vnhKGANQKpsaIMVa'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 267000,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'ESA011801411'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/66HxHtqsgk2NgVQRqEgxyb'},
#      'href': 'https://api.spotify.com/v1/tracks/66HxHtqsgk2NgVQRqEgxyb',
#      'id': '66HxHtqsgk2NgVQRqEgxyb',
#      'is_local': False,
#      'name': 'WTF Is In My Cup',
#      'popularity': 43,
#      'preview_url': 'https://p.scdn.co/mp3-preview/62536ac88b93600c2e39f69737ebf0bbf6f9f16a?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:66HxHtqsgk2NgVQRqEgxyb'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-01-19T07:52:44Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/toni085'},
#      'href': 'https://api.spotify.com/v1/users/toni085',
#      'id': 'toni085',
#      'type': 'user',
#      'uri': 'spotify:user:toni085'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#         'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#         'id': '12Chz98pHFMPJEknJQMWvI',
#         'name': 'Muse',
#         'type': 'artist',
#         'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5OZgDtx180ZZPMpm36J2zC'},
#       'href': 'https://api.spotify.com/v1/albums/5OZgDtx180ZZPMpm36J2zC',
#       'id': '5OZgDtx180ZZPMpm36J2zC',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734cb163c1d111f77307c842b6',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024cb163c1d111f77307c842b6',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514cb163c1d111f77307c842b6',
#         'width': 64}],
#       'name': 'Simulation Theory (Super Deluxe)',
#       'release_date': '2018-11-09',
#       'release_date_precision': 'day',
#       'total_tracks': 21,
#       'type': 'album',
#       'uri': 'spotify:album:5OZgDtx180ZZPMpm36J2zC'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#        'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#        'id': '12Chz98pHFMPJEknJQMWvI',
#        'name': 'Muse',
#        'type': 'artist',
#        'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 245960,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAHT1800406'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7f0vVL3xi4i78Rv5Ptn2s1'},
#      'href': 'https://api.spotify.com/v1/tracks/7f0vVL3xi4i78Rv5Ptn2s1',
#      'id': '7f0vVL3xi4i78Rv5Ptn2s1',
#      'is_local': False,
#      'name': 'Algorithm',
#      'popularity': 54,
#      'preview_url': 'https://p.scdn.co/mp3-preview/00d386644c07673f05878e337f977911c0ba740b?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:7f0vVL3xi4i78Rv5Ptn2s1'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-01-22T12:49:54Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/copia002'},
#      'href': 'https://api.spotify.com/v1/users/copia002',
#      'id': 'copia002',
#      'type': 'user',
#      'uri': 'spotify:user:copia002'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KeIof0zqga5ojkmOKg88P'},
#         'href': 'https://api.spotify.com/v1/artists/1KeIof0zqga5ojkmOKg88P',
#         'id': '1KeIof0zqga5ojkmOKg88P',
#         'name': 'Plastic Bertrand',
#         'type': 'artist',
#         'uri': 'spotify:artist:1KeIof0zqga5ojkmOKg88P'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1wLw41yiDGcZowrw3L3Bkd'},
#       'href': 'https://api.spotify.com/v1/albums/1wLw41yiDGcZowrw3L3Bkd',
#       'id': '1wLw41yiDGcZowrw3L3Bkd',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273168b00b7ccd04a5cf38cd74e',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02168b00b7ccd04a5cf38cd74e',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851168b00b7ccd04a5cf38cd74e',
#         'width': 64}],
#       'name': 'Plastic Bertrand',
#       'release_date': '1998-02-06',
#       'release_date_precision': 'day',
#       'total_tracks': 19,
#       'type': 'album',
#       'uri': 'spotify:album:1wLw41yiDGcZowrw3L3Bkd'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KeIof0zqga5ojkmOKg88P'},
#        'href': 'https://api.spotify.com/v1/artists/1KeIof0zqga5ojkmOKg88P',
#        'id': '1KeIof0zqga5ojkmOKg88P',
#        'name': 'Plastic Bertrand',
#        'type': 'artist',
#        'uri': 'spotify:artist:1KeIof0zqga5ojkmOKg88P'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 182133,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'BEB017765001'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/71yCMlsD6qbD7NmNUEoVNR'},
#      'href': 'https://api.spotify.com/v1/tracks/71yCMlsD6qbD7NmNUEoVNR',
#      'id': '71yCMlsD6qbD7NmNUEoVNR',
#      'is_local': False,
#      'name': 'Ca plane pour moi',
#      'popularity': 62,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7c7cf670d7afe4ce21cd73cc6e6d2628c22c1f14?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:71yCMlsD6qbD7NmNUEoVNR'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-01-22T12:52:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/soyungalgo'},
#      'href': 'https://api.spotify.com/v1/users/soyungalgo',
#      'id': 'soyungalgo',
#      'type': 'user',
#      'uri': 'spotify:user:soyungalgo'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kL2dtCF73efjph3etoBAs'},
#         'href': 'https://api.spotify.com/v1/artists/1kL2dtCF73efjph3etoBAs',
#         'id': '1kL2dtCF73efjph3etoBAs',
#         'name': 'Pedro LaDroga',
#         'type': 'artist',
#         'uri': 'spotify:artist:1kL2dtCF73efjph3etoBAs'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
# ...
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 340669,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'FR9W11816827'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7wpU5lCOnvH7eDFjwSStFa'},
#      'href': 'https://api.spotify.com/v1/tracks/7wpU5lCOnvH7eDFjwSStFa',
#      'id': '7wpU5lCOnvH7eDFjwSStFa',
#      'is_local': False,
#      'name': 'Silver',
#      'popularity': 46,
#      'preview_url': 'https://p.scdn.co/mp3-preview/3f6c089a0a548b700f7512187a8ac29bdf7daf91?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:7wpU5lCOnvH7eDFjwSStFa'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-06-05T17:49:51Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/toni085'},
#      'href': 'https://api.spotify.com/v1/users/toni085',
#      'id': 'toni085',
#      'type': 'user',
#      'uri': 'spotify:user:toni085'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0cwmNvclzPd8mQnoHuIksj'},
#         'href': 'https://api.spotify.com/v1/artists/0cwmNvclzPd8mQnoHuIksj',
#         'id': '0cwmNvclzPd8mQnoHuIksj',
#         'name': 'Vengaboys',
#         'type': 'artist',
#         'uri': 'spotify:artist:0cwmNvclzPd8mQnoHuIksj'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4IN8XgCPFmB7EHRD73vOlV'},
#       'href': 'https://api.spotify.com/v1/albums/4IN8XgCPFmB7EHRD73vOlV',
#       'id': '4IN8XgCPFmB7EHRD73vOlV',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27345727502ff23deff131da187',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0245727502ff23deff131da187',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485145727502ff23deff131da187',
#         'width': 64}],
#       'name': 'Up & Down',
#       'release_date': '1998',
#       'release_date_precision': 'year',
#       'total_tracks': 8,
#       'type': 'album',
#       'uri': 'spotify:album:4IN8XgCPFmB7EHRD73vOlV'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0cwmNvclzPd8mQnoHuIksj'},
#        'href': 'https://api.spotify.com/v1/artists/0cwmNvclzPd8mQnoHuIksj',
#        'id': '0cwmNvclzPd8mQnoHuIksj',
#        'name': 'Vengaboys',
#        'type': 'artist',
#        'uri': 'spotify:artist:0cwmNvclzPd8mQnoHuIksj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 240753,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'NLC529811111'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4L54iRvfSVTa48NxYhHBIu'},
#      'href': 'https://api.spotify.com/v1/tracks/4L54iRvfSVTa48NxYhHBIu',
#      'id': '4L54iRvfSVTa48NxYhHBIu',
#      'is_local': False,
#      'name': 'Up & Down',
#      'popularity': 62,
#      'preview_url': 'https://p.scdn.co/mp3-preview/3583d855f959bed6993cac12adc5ab217b374602?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4L54iRvfSVTa48NxYhHBIu'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-06-11T07:26:38Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1182774545'},
#      'href': 'https://api.spotify.com/v1/users/1182774545',
#      'id': '1182774545',
#      'type': 'user',
#      'uri': 'spotify:user:1182774545'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73A3bLnfnz5BoQjb4gNCga'},
#         'href': 'https://api.spotify.com/v1/artists/73A3bLnfnz5BoQjb4gNCga',
#         'id': '73A3bLnfnz5BoQjb4gNCga',
#         'name': 'Bicep',
#         'type': 'artist',
#         'uri': 'spotify:artist:73A3bLnfnz5BoQjb4gNCga'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4psDRFbIlUM1KUb1omccXo'},
#       'href': 'https://api.spotify.com/v1/albums/4psDRFbIlUM1KUb1omccXo',
#       'id': '4psDRFbIlUM1KUb1omccXo',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273d4322a9004288009f6da2975',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02d4322a9004288009f6da2975',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851d4322a9004288009f6da2975',
#         'width': 64}],
#       'name': 'Bicep',
#       'release_date': '2017-09-01',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:4psDRFbIlUM1KUb1omccXo'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73A3bLnfnz5BoQjb4gNCga'},
#        'href': 'https://api.spotify.com/v1/artists/73A3bLnfnz5BoQjb4gNCga',
#        'id': '73A3bLnfnz5BoQjb4gNCga',
#        'name': 'Bicep',
#        'type': 'artist',
#        'uri': 'spotify:artist:73A3bLnfnz5BoQjb4gNCga'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 269149,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBCFB1700229'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2aJDlirz6v2a4HREki98cP'},
#      'href': 'https://api.spotify.com/v1/tracks/2aJDlirz6v2a4HREki98cP',
#      'id': '2aJDlirz6v2a4HREki98cP',
#      'is_local': False,
#      'name': 'Glue',
#      'popularity': 71,
#      'preview_url': 'https://p.scdn.co/mp3-preview/2cdf855e1b77f80eb4e9291d0dd55c383f5aa83c?cid=4774f2bf3e2e4694b6872c006b3b8cbd',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:2aJDlirz6v2a4HREki98cP'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 67},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:4UbChG0JiHRFrwjvQvG2LJ'}

# %%
def getUserSongArtist(playlist):
    """
    Extraemos la información que necesitamos de la lista
    y devuelve un dataframae
    """
    lista = playlist['tracks']['items']
    toda_info = []
    for tema in range(len(lista)):
        temporal = {}
        temporal["artista"] = lista[tema]['track']['artists'][0]['name']
        temporal["nombre"] = lista[tema]['track']['name']
        temporal["ironhacker"] = lista[tema]['added_by']['id']
        toda_info.append(temporal)
    
    return pd.DataFrame(toda_info)

# %%
def make_all(playlist_id):
    playlist = spotifyPlaylist(playlist_id)
    return getUserSongArtist(playlist)

# %%
make_all("4UbChG0JiHRFrwjvQvG2LJ")
# Out:
#           artista                          nombre     ironhacker
# 0   Fuel Fandango  Mi danza (feat. Dani de Morón)     soyungalgo
# 1          Zahara                       MERICHANE     soyungalgo
# 2       LOS NIKIS                 Olaf el vikingo        toni085
# 3        rusowsky                           So So  ferqwertyuiop
# 4    Chico Blanco                WTF Is In My Cup     1182774545
# ..            ...                             ...            ...
# 62        Samaran                   Paris Madness     1182774545
# 63    Lewis OfMan                        Attitude     1182774545
# 64        Gavinco                          Silver     1182774545
# 65      Vengaboys                       Up & Down        toni085
# 66          Bicep                            Glue     1182774545
#
# [67 rows x 3 columns]

# %%
make_all("6TRHP4Bpss2ZBfUwSslgpN")
# Out:
#                 artista               nombre ironhacker
# 0          Ryan Bingham             The Poet
# 1          Ryan Bingham    Don't Wait For Me
# 2          Ryan Bingham        The Wandering
# 3            Ben Howard    Keep Your Head Up
# 4            Ben Howard        Follaton Wood
# ..                  ...                  ...        ...
# 95  The Gaslight Anthem      National Anthem  bleboch16
# 96  The Felice Brothers       Wonderful Life  bleboch16
# 97         Jimmy LaFave       Only One Angel  bleboch16
# 98             Max Jury           All I Want  bleboch16
# 99       Treetop Flyers  Is It All Worth It?  bleboch16
#
# [100 rows x 3 columns]

# %% [markdown]
# # 📚 Recap hasta ahora:
#
# **Lo que hicimos**
# - 1. Hicimos una llamada a la API de Spotify: para obtener la información de la lista
# - 2. Obtenemos sólo las canciones y los artistas del json
# - 3. Hacemos funcionoes que automatizan procesos y reutilizan códigoo
# - 4. Tenemos un dataframe
# <br>
#
# **Para recordar**
#
# - Añade el `.env` al `.gitignore`.

# %% [markdown]
#  ## Misión 3
#  # <center> Obtener las letras de las canciones con "lyrics_extractor"</center>
# ## Extraemos letras de las canciones!
# Lyrics extractor es una librería que escrapea por nosotras algunas páginas de letras de canciones.
# Echamos un ojo a la [documentación](https://pypi.org/project/lyrics-extractor/) SIEMPRE, sobre todo a la parte de **Requirements** que nos va a explicar las cosas que necesitamos tener para que funcione.
# ### Necesitamos crear las KEYs para esta librería
# 1.1.1. **[Primero](https://cse.google.com/cse/create/new)**, crear un motor de búsqueda personalizado: seleccionar un sitio web de letras para raspar. por ejemplo: www.genius.com <br>
# 1.1.2. **Segundo**, `Edita tu motor de búsqueda > selecciona tu web > Copia tu ID de motor de búsqueda`.
# Ahora tiene su **GCS_ENGINE_ID**<br>
# 1.1.3. **[Entonces](https://developers.google.com/custom-search/v1/overview)**, `Obtener una clave > Seleccionar proyecto > copiar la clave API del buscador`. Ahora tiene su **GCS_API_KEY**.

# %%
from lyrics_extractor import SongLyrics

# %% [markdown]
# ### Como la librería necesita las keys, las sacamos del .env

# %%
GCS_API_KEY = os.getenv("GCS_API_KEY")
GCS_ENGINE_ID = os.getenv("GCS_ENGINE_ID")

# %% [markdown]
# ### La guardamos en una variable
# Guardamos la librería en una variable llamando a SongLyrics y pasándole las claves

# %% [markdown]
# ### Buscamos una letra

# %%
#letra

# %%
# Esta librería nos devuelve un diccionario del que solo queremos un value concreto

# %% [markdown]
# ### ¡¡Muchas letras!!

# %% [markdown]
# ### Creamos una columna nueva con las letras

# %%
4UbChG0JiHRFrwjvQvG2LJ

# %% [markdown]
# ### Exportamos los datos
